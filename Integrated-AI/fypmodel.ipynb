# %%
import sys
print(sys.executable)
# !pip install xgboost
# Out:
# /usr/bin/python3
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xgboost
#   Using cached xgboost-1.7.5-py3-none-manylinux2014_x86_64.whl (200.3 MB)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from xgboost) (1.8.0)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.5

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np
from sklearn.metrics import confusion_matrix
from tensorflow.keras import models, layers
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('fypdata.csv', encoding='utf-8-sig')
X = df['Sentence']
y = df['Label']

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/labuser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
vectorizer = CountVectorizer(min_df = 2, max_df = 0.8, stop_words = stopwords.words('english'))
X = vectorizer.fit_transform(X.values.astype('U')).toarray()
#these above 1 lines variabel .astype
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (23903, 13324)
# (23903,)
# (5976, 13324)
# (5976,)

# %%
m1 = LogisticRegression()
m1.fit(X_train, y_train)
y_pred = m1.predict(X_test)
print(f"Accuracy of Logistic Regression on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Logistic Regression on test set : {f1_score(y_pred, y_test)}")
confusion = confusion_matrix(y_test, y_pred)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]

sensitivity = TP / float(FN + TP)

print("sensitivity=",sensitivity)
specificity = TN / (TN + FP)
print("specificity=",specificity)


Precision = TP / float(TP + FP)
Recall = TP / float(TP + FN)
F1 = 2*((Precision*Recall)/(Precision+Recall))
print ("Precision=",Precision)
# Out:
# Accuracy of Logistic Regression on test set : 0.9943105756358769
# F1 Score of Logistic Regression on test set : 0.994904076738609
# sensitivity= 0.9898598270205786
# specificity= 1.0
# Precision= 1.0

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
m2 = AdaBoostClassifier(n_estimators=100)
m2.fit(X_train, y_train)
y_pred = m2.predict(X_test)
print(f"Accuracy of AadaBoost on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of AadaBoost on test set : {f1_score(y_pred, y_test)}")
confusion = confusion_matrix(y_test, y_pred)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]

sensitivity = TP / float(FN + TP)

print("sensitivity=",sensitivity)
specificity = TN / (TN + FP)
print("specificity=",specificity)


Precision = TP / float(TP + FP)
Recall = TP / float(TP + FN)
F1 = 2*((Precision*Recall)/(Precision+Recall))
print ("Precision=",Precision)
# Out:
# Accuracy of AadaBoost on test set : 0.9912985274431058
# F1 Score of AadaBoost on test set : 0.9921992199219921
# sensitivity= 0.9862809424396063
# specificity= 0.9977125428898208
# Precision= 0.9981889526109267

# %%
m3 = GaussianNB()
m3.fit(X_train, y_train)
y_pred = m3.predict(X_test)
print(f"Accuracy of Naive Bayes on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Naive Bayes on test set : {f1_score(y_pred, y_test)}")

confusion = confusion_matrix(y_test, y_pred)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]

sensitivity = TP / float(FN + TP)

print("sensitivity=",sensitivity)
specificity = TN / (TN + FP)
print("specificity=",specificity)


Precision = TP / float(TP + FP)
Recall = TP / float(TP + FN)
F1 = 2*((Precision*Recall)/(Precision+Recall))
print ("Precision=",Precision)
# Out:
# Accuracy of Naive Bayes on test set : 0.8920682730923695
# F1 Score of Naive Bayes on test set : 0.9120894098405343
# sensitivity= 0.9979123173277662
# specificity= 0.7567670606176135
# Precision= 0.839859437751004

# %%
import xgboost as xgb

# %%
m4 = xgb.XGBClassifier(n_estimators=100)
m4.fit(X_train, y_train)
y_pred = m4.predict(X_test)
print(f"Accuracy of XGBoost on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of XGBoost on test set : {f1_score(y_pred, y_test)}")
confusion = confusion_matrix(y_test, y_pred)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]

sensitivity = TP / float(FN + TP)

print("sensitivity=",sensitivity)
specificity = TN / (TN + FP)
print("specificity=",specificity)


Precision = TP / float(TP + FP)
Recall = TP / float(TP + FN)
F1 = 2*((Precision*Recall)/(Precision+Recall))
print ("Precision=",Precision)
# Out:
# Accuracy of XGBoost on test set : 0.9924698795180723
# F1 Score of XGBoost on test set : 0.9932503374831259
# sensitivity= 0.9874739039665971
# specificity= 0.9988562714449104
# Precision= 0.9990947495473748

# %%
import numpy as nm  
import matplotlib.pyplot as mtp
from sklearn.tree import DecisionTreeClassifier

# %%
m5 = DecisionTreeClassifier(criterion='entropy', random_state=0)
m5.fit(X_train, y_train)
y_pred = m5.predict(X_test)
print(f"Accuracy of Decision Tree on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Decision Tree on test set : {f1_score(y_pred, y_test)}")
confusion = confusion_matrix(y_test, y_pred)

TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]

sensitivity = TP / float(FN + TP)

print("sensitivity=",sensitivity)
specificity = TN / (TN + FP)
print("specificity=",specificity)


Precision = TP / float(TP + FP)
Recall = TP / float(TP + FN)
F1 = 2*((Precision*Recall)/(Precision+Recall))
print ("Precision=",Precision)
# Out:
# Accuracy of Decision Tree on test set : 0.9944779116465864
# F1 Score of Decision Tree on test set : 0.9950680017934539
# sensitivity= 0.9928422308380555
# specificity= 0.9965688143347312
# Precision= 0.9973037747153984

# %%
import pickle
# save the model to disk
filename1 = 'm1.sav'
filename2 = 'm2.sav'
filename3 = 'm3.sav'
filename4 = 'm4.sav'
filename5 = 'm5.sav'
pickle.dump(m1, open("m1.sav", 'wb'))
pickle.dump(m2, open("m2.sav", 'wb'))
pickle.dump(m3, open("m3.sav", 'wb'))
pickle.dump(m4, open("m4.sav", 'wb'))
pickle.dump(m5, open("m5.sav", 'wb'))

# %%
#start from here after training 
import pickle
m1 = pickle.load(open("m1.sav", 'rb'))
m2 = pickle.load(open("m2.sav", 'rb'))
m3 = pickle.load(open("m3.sav", 'rb'))
m4 = pickle.load(open("m4.sav", 'rb'))
m5 = pickle.load(open("m5.sav", 'rb'))

sqlvb2 = ["hello"]



import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import numpy as np
from sklearn.metrics import confusion_matrix
from tensorflow.keras import models, layers
import warnings

warnings.filterwarnings('ignore')

df = pd.read_csv('fypdata.csv', encoding='utf-8-sig')
X = df['Sentence']
y = df['Label']

import nltk

nltk.download('stopwords')
vectorizer = CountVectorizer(min_df = 2, max_df = 0.8, stop_words = stopwords.words('english'))
X = vectorizer.fit_transform(X.values.astype('U')).toarray()
#these above 1 lines variabel .astype
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

s = vectorizer.transform(sqlvb2).toarray()
m1_pred = m1.predict(s)
m2_pred = m2.predict(s)
m3_pred = m3.predict(s)
m4_pred = m4.predict(s)
m5_pred = m5.predict(s)
print(m1_pred)
print(m2_pred)
print(m3_pred)
print(m4_pred)
print(m5_pred)
# Out:
# 2023-05-05 11:37:27.271315: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-05 11:37:27.592763: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-05 11:37:27.593947: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-05 11:37:29.221076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package stopwords to /home/dell/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# (23903, 13324)
# (23903,)
# (5976, 13324)
# (5976,)
# [0]
# [0]
# [1]
# [0]
# [0]

# %%
import mysql.connector
import time
from mysql.connector import errorcode

# Establish a connection to the MySQL server
cnx = mysql.connector.connect(
    host="localhost",
    user="puser",
    password="password",
    database="fyp"
)

# Create a cursor object
cursor = cnx.cursor()

# Define the INSERT statement
query = "INSERT INTO logs (source_IP, dest_IP, payload,attack) VALUES (%s, %s, %s,%s)"


# Define the values to be inserted
values = ("AI", "is", "now","Connected")

# Execute the INSERT statement
cursor.execute(query, values)

# Commit the changes to the daatbase
cnx.commit()



# Define the INSERT statement
query = "select * from logs;"

query = "drop table ailogs";
cursor.execute(query)
query = "CREATE TABLE ailogs (id INT AUTO_INCREMENT PRIMARY KEY, LogisticRegression INT, AdaBoostClassifier INT, GaussianNB INT, XGBClassifier INT, DecisionTreeClassifier INT,total int,attack varchar(255));"


# Execute the INSERT statement
cursor.execute(query)



# Close the cursor and connection objects
#cursor.close()
#cnx.close()
sqlvb2 = ["hello"]
s = vectorizer.transform(sqlvb2).toarray()
m1_pred = m1.predict(s)
m2_pred = m2.predict(s)
m3_pred = m3.predict(s)
m4_pred = m4.predict(s)
m5_pred = m5.predict(s)
print(m1_pred)
print(m2_pred)
print(m3_pred)
print(m4_pred)
print(m5_pred)

query = "SELECT * FROM logs ORDER BY id DESC LIMIT 1;"
cursor.execute(query)
row = cursor.fetchall()
print(row)
update = (row[0])[0]

passed=1

while(1):
    try:
        cnx = mysql.connector.connect(
        host="localhost",
        user="puser",
        password="password",
        database="fyp"
        )
        # create cursor object
        cursor = cnx.cursor()
        query = "SELECT * FROM logs ORDER BY id DESC LIMIT 1;"
        cursor.execute(query)
        row = cursor.fetchall()
        print(row)
        update = (row[0])[0]
        print(update)
        if update != passed:
            passed=update
            sqlvb2 = [(row[0])[3]]
            s = vectorizer.transform(sqlvb2).toarray()
            m1_pred = m1.predict(s)
            m2_pred = m2.predict(s)
            m3_pred = m3.predict(s)
            m4_pred = m4.predict(s)
            m5_pred = m5.predict(s)
            print(m1_pred)
            print(m2_pred)
            print(m3_pred)
            print(m4_pred)
            print(m5_pred)
            t=int(m1_pred[0])+int(m2_pred[0])+int(m3_pred[0])+ int(m4_pred[0])+ int(m5_pred[0])
            query = "INSERT INTO ailogs (LogisticRegression, AdaBoostClassifier, GaussianNB, XGBClassifier, DecisionTreeClassifier, total,attack) VALUES (%s, %s, %s, %s, %s, %s,%s);"
            # Define the values to be inserted
            values = (int(m1_pred[0]), int(m2_pred[0]), int(m3_pred[0]), int(m4_pred[0]), int(m5_pred[0]), t,(row[0])[4])
            # Execute the INSERT statement
            cursor.execute(query, values)
            # Commit the changes to the daatbase
            cnx.commit()
        else:
            time.sleep(2)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
            print("Something is wrong with your user name or password")
        elif err.errno == errorcode.ER_BAD_DB_ERROR:
            print("Database does not exist")
        elif err.errno == errorcode.CR_CONN_HOST_ERROR:
            print("Connection error")
        elif err.errno == errorcode.CR_CONN_HOST_ERROR:
            print("Connection error")
        elif err.errno == errorcode.CR_SERVER_LOST:
            print("Connection lost, retrying")
            cnx.close()
        else:
            print(err)
        time.sleep(2) # sleep before attempting to reconnect
# Out:
# [0]
# [0]
# [1]
# [0]
# [0]
# [(1, 'AI', 'is', 'now', 'Connected')]
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(1, 'AI', 'is', 'now', 'Connected')]
# 1
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [0]
# [0]
# [1]
# [0]
# [0]
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(3, '172.17.0.2', '172.17.0.1', 'TCP scan', 'Scaning network')]
# 3
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [1]
# [1]
# [1]
# [1]
# [1]
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(7, '172.17.0.2', '172.17.0.1', 'whoami', 'RCE')]
# 7
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [0]
# [0]
# [1]
# [0]
# [1]
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# ...
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
# [(11, '172.17.0.2', '172.17.0.1', '.exe', 'MFE')]
# 11
